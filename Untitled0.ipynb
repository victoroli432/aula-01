# %% [markdown]
# <a href="https://colab.research.google.com/github/victoroli432/aula-01/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from io import BytesIO

import requests
import pandas as pd

# https://colab.research.google.com/drive/1IdiL3wy5yMZxWpqwDtwnTQtUnwtS3JPY?usp=sharing

df = pd.read_csv('https://github.com/victoroli432/aula-01/raw/main/Base%20de%20dados.csv', encoding = 'utf-8', sep = ';')
df.head()
# Out:
#   Estado - Sigla Municipio                                      Revenda  \
# 0             SP  CAMPINAS                          POSTO DE PONTA LTDA
# 1             SP  CAMPINAS                          POSTO DE PONTA LTDA
# 2             SP  CAMPINAS                          ANDRÉA SANTINI REGO
# 3             SP  CAMPINAS                          ANDRÉA SANTINI REGO
# 4             SP  CAMPINAS  NOTRE DAME AUTO POSTO DE COMBUSTÍVEIS LTDA.
#
#             Nome da Rua         Bairro        Cep   Produto Data da Coleta  \
# 0  AVENIDA SANTA IZABEL  BARAO GERALDO  13024-500  GASOLINA     05/01/2021
# 1  AVENIDA SANTA IZABEL  BARAO GERALDO  13024-500    ETANOL     05/01/2021
# 2        AVENIDA BRASIL      GUANABARA  13023-020  GASOLINA     05/01/2021
# 3        AVENIDA BRASIL      GUANABARA  13023-020    ETANOL     05/01/2021
# 4    RUA ADALBERTO MAIA       TAQUARAL  13076-007  GASOLINA     05/01/2021
#
#   Valor de Venda Unidade de Medida  Bandeira
# ...

# %%
df.shape
# Out:
# (4273, 11)

# %%
df[['Revenda','Produto','Valor de Venda']].head()
# Out:
#                                        Revenda   Produto Valor de Venda
# 0                          POSTO DE PONTA LTDA  GASOLINA          4,299
# 1                          POSTO DE PONTA LTDA    ETANOL          3,099
# 2                          ANDRÉA SANTINI REGO  GASOLINA          4,299
# 3                          ANDRÉA SANTINI REGO    ETANOL          3,099
# 4  NOTRE DAME AUTO POSTO DE COMBUSTÍVEIS LTDA.  GASOLINA          3,999

# %%
if (df['Valor de Venda'] < 2):
                      print('Muito Barato')
if (2 < df['Valor de Venda'] < 4):
                      print('Barato')
if (4 < df['Valor de Venda'] < 6):
                      print('NORMAL')
if (6 < df['Valor de Venda']):
                      print('Muito caro')    

df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-201eba0beaa9> in <module>
# ----> 1 if (df['Valor de Venda'] < 2):
#       2                       print('Muito Barato')
#       3 if (2 < df['Valor de Venda'] < 4):
#       4                       print('Barato')
#       5 if (4 < df['Valor de Venda'] < 6):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# ...
